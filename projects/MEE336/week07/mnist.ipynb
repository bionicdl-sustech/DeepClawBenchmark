# %% [markdown]
# This original source of this tutorial is [here](https://www.tensorflow.org/tutorials/quickstart/beginner).
#
# The [MNIST](http://yann.lecun.com/exdb/mnist/) database of handwritten digits, has a training set of 60,000 examples, and a test set of 10,000 examples. It is a subset of a larger set available from NIST. The digits have been size-normalized and centered in a fixed-size image.

# %%
# from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import numpy as np

# %%
temp=np.load('./mnist.npz')
print(temp.files)
# Out:
# ['x_test', 'x_train', 'y_train', 'y_test']

# %%
x_train = temp['x_train']
y_train = temp['y_train']
x_test = temp['x_test']
y_test = temp['y_test']

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)

model.evaluate(x_test,  y_test, verbose=2)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2981 - accuracy: 0.9153
# Epoch 2/5
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.1452 - accuracy: 0.9567
# Epoch 3/5
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.1085 - accuracy: 0.9678
# Epoch 4/5
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0900 - accuracy: 0.9722
# Epoch 5/5
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0757 - accuracy: 0.9767
# 10000/1 - 0s - loss: 0.0373 - accuracy: 0.9777
# [0.07288527335491962, 0.9777]
